# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import statsmodels.api as sm
import os

# %%
os.getcwd()

data = pd.read_csv('Real_estate_valuation_dataset.csv') # Read .csv dataset

#Q1: Check the first five rows of the data
data.head()
# Out:
#    houseAge  distanceToNearestMRTStation  numberOfConvenienceStores  latitude  \
# 0      32.0                     84.87882                         10  24.98298
# 1      19.5                    306.59470                          9  24.98034
# 2      13.3                    561.98450                          5  24.98746
# 3      13.3                    561.98450                          5  24.98746
# 4       5.0                    390.56840                          5  24.97937
#
#    longitude  housePriceUnitArea
# 0  121.54024                37.9
# 1  121.53951                42.2
# 2  121.54391                47.3
# 3  121.54391                54.8
# 4  121.54245                43.1

# %%
#Q2:  Check the shape, i.e., the dimensions of your data file
data.shape
# Out:
# (414, 6)

# %%
#Q3:  Check if there is any NaN values
data.isna()
# Out:
#      houseAge  distanceToNearestMRTStation  numberOfConvenienceStores  \
# 0       False                        False                      False
# 1       False                        False                      False
# 2       False                        False                      False
# 3       False                        False                      False
# 4       False                        False                      False
# 5       False                        False                      False
# 6       False                        False                      False
# 7       False                        False                      False
# 8       False                        False                      False
# 9       False                        False                      False
# 10      False                        False                      False
# 11      False                        False                      False
# ...

# %%
#Q4: Split the dataset into two parts, 80% for training and 20% for testing
#Assign an integer to random_state and it is the seed used by the random number generator
mask = np.random.rand(len(data)) < 0.8
train = data[mask]
test = data[~mask]
print(len(train))
print(len(test))
# Out:
# 321
# 93

# %%
#Q5: Let x in the training set be the variable without housePriceUnitArea
# Please do this for both 'train' & 'test' datasets

# %%
#Q6: Let y in the testing set be "housePriceUnitArea"
# Please do this for both 'train' & 'test' datasets

# %%
# Q7: Create array of histograms and scatter plots for 'train' dataset, like the one on Slide #16 in Lecture 9 notes

# %%
# Show the Pearson Correlation map
def correlation_heatmap(data):
    _, ax = plt.subplots(
        figsize=(14, 12))  # Only ax is used in following code, we do not assign value to the other variable
    colormap = sns.diverging_palette(220, 10, as_cmap=True)

    sns.heatmap(
        data.corr(),
        cmap=colormap,
        square=True,
        cbar_kws={'shrink': .9},
        ax=ax,
        annot=True,
        linewidths=0.1, vmax=1.0, linecolor='white',
        annot_kws={'fontsize': 12}
    )

    plt.title('Pearson Correlation of Features', y=1.05, size=15)


correlation_heatmap(train)  # Input train_df to the function, and check the correlation of all variables

# %%
#Q8: Fit linear regression to training data, use appropriate package function
linear_regression = # use the function here!

print('The intercept estimated by Sklearn is ', linear_regression.intercept_)
print('The coefficients estimated by Sklearn are ',linear_regression.coef_)
# Out:
# The intercept estimated by Sklearn is  -6492.844323333305
# The coefficients estimated by Sklearn are  [-2.72651370e-01 -4.01011412e-03  1.28588958e+00  2.37407377e+02
#   4.99405501e+00]

# %%
#Q9: Prepare the X data matrix for your own Linear Regression Function
#    Add a constant term in dataframe for linear regression
X_train = x_train.copy()
X_test = x_test.copy()

# Please add the '1' column here for X_train

# Please add the '1' column here for X_test
# Out:
#      Constant  houseAge  distanceToNearestMRTStation  \
# 328         1      15.9                    1497.7130
# 363         1      32.3                     109.9455
# 298         1      16.7                    4082.0150
# 153         1       6.5                     376.1709
# 219         1      29.3                     529.7771
#
#      numberOfConvenienceStores  latitude  longitude
# 328                          3  24.97003  121.51696
# 363                         10  24.98182  121.54086
# 298                          0  24.94155  121.50381
# 153                          6  24.95418  121.53713
# 219                          8  24.98102  121.53655

# %%
# Show the X_train data matrix with column of '1's
X_train = X_train[['Constant', 'houseAge', 'distanceToNearestMRTStation', 'numberOfConvenienceStores','latitude','longitude']]
X_train.head()

# %%
# Show the X_test data matrix with column of '1's
X_test = X_test[['Constant', 'houseAge', 'distanceToNearestMRTStation', 'numberOfConvenienceStores','latitude','longitude']]
X_test.head()

# %%
#Q10: Define a function to calculate the Linear Regression model coefficient vector, w*. Fill the missing codes
def get_LR_OLS_Coef(X, Y):
    inverse_matrix = np.linalg.inv(# Complete this calculation
    hat_matrix = # Complete this calculation
    est_coeff = # Complete this calculation
    
    print('Coefficients estimated by the formula is ', est_coeff)
    
    return est_coeff
# Out:
# Coefficients estimated by the formula is  [-6.49284523e+03 -2.72651370e-01 -4.01011404e-03  1.28588958e+00
#   2.37407378e+02  4.99406217e+00]

# %%
#Q11: Check the significance of parameters, using the package function for OLS
# and print the summary of the model
lr = # train your model here, Complete this calculation
lr_result = # generate the fit, Complete this calculation
print(lr_result.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:     housePriceUnitArea   R-squared (uncentered):                   0.949
# Model:                            OLS   Adj. R-squared (uncentered):              0.949
# Method:                 Least Squares   F-statistic:                              1378.
# Date:                Fri, 04 Oct 2019   Prob (F-statistic):                   2.70e-235
# Time:                        11:08:00   Log-Likelihood:                         -1348.1
# No. Observations:                 372   AIC:                                      2706.
# Df Residuals:                     367   BIC:                                      2726.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %%
#Q12: instead of using the library (followin commented command), prediction can be done as follows
# y_predict = linear_regression.predict(x_test) #Predict y based on test dataset
def get_Precited_Y(X, Model_Coef):
    
    # Please complete this function with np.dot()
    y_predict = 
    
    return y_predict.transpose()
# Out:
# //anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
#Q13: Use scipy to plot QQ plot to check the normality assumption
# Complet the following syntax
# stats.probplot()

# %%
#Q14: Check the zero mean residual assumption with Residual Residual v.s Fitted plot
# get the predicted output from the model learned previously
w_star = get_LR_OLS_Coef # Complete this function loading ()
y_hat = get_Precited_Y # Complete this function loading ()

# get the residules of the data objects
residuals = # Complete this calculation

# plot the figure
plt.scatter(linear_regression.predict(x_train), residuals)
plt.xlabel('Fitted values')
plt.title('Residual vs Fitted')
plt.axhline(y = 0, color = 'grey', ls = '--')
plt.show()

# %%
#Q15: Check the constant residual assumption with Scale-Location plot

# Use the 'residuals' calculated previously 
standardized_residuals = # Complete this calculation

plt.scatter(y_hat, np.sqrt(abs(standardized_residuals)))
plt.xlabel('Fitted values')
plt.title('Scale-Location')
plt.draw()
plt.show()

# %%
#Q16: Create a pandas dataframe with two columns, one is the real value callded "True Values" from our testing dataset, and the other on is the predicted values called "Predicted Values" based on the regression model
y_hat_test = # Complete this command
y_hat_test = pd.Series(y_hat_test)
y_test = y_test.reset_index()
y_test = y_test.drop(['index'], axis = 1)
y_test = y_test.transpose().iloc[0]
compare = pd.DataFrame({# Complete this command

compare.reset_index(inplace = True)
compare = compare.drop(['index'], axis = 1)
compare.head()

compare.plot()
plt.title('Ture values vs. Predicted Values')

# %%
#Plot residuals in testing dataset
plt.plot(compare['Predicted Values'] - compare['True Values'])
plt.title('Residual Plot')

# %%
#Q17 Define a function that calculates R^2
# Please use your own function, 'get_LR_OLS_Coef(X, Y)' & 'get_Precited_Y(X, Model_Coef)''
def R2(X_, Y_):
    X_ = sm.add_constant(X_)
    
    # Calculate the model coefficients for the given inputs and outputs
    Mdl_Coef = # Complete this command
    
    # calculate y_hat: y_hat = est_coeff . x_train_transpoed
    y_hat = # Complete this command

    compare = pd.DataFrame({'y_true': Y_, 'y_hat': y_hat})
    compare.reset_index(inplace=True)
    compare = compare.drop(['index'], axis=1)
    y_bar = compare["y_true"].mean()

    # Calculate SSR and SSE based on the example provided for SST.

    SST = 0
    for i in range(0, len(compare['y_hat'] - 1)):
        SST = SST + pow((compare['y_true'][i] - y_bar), 2)

    SSR = 0
    # write a loop to calculate SSR: similar to fist loop



    SSE = 0
    # write a loop to calculate SSE: similar to fist loop



    # calculate R2
    R_sqr = # Complete this command

    print('R^2 is ', R_sqr)

    return R_sqr, SST, SSR, SSE
# Out:
#   File "<ipython-input-1-ead0ec8d4404>", line 7
#     Mdl_Coef = # Complete this command
#                                       ^
# SyntaxError: invalid syntax

# %%
print('housePriceUnitArea = w0 + w1*houseAge')
r1, SST1, SSR1, SSE1 = R2(x_train[['houseAge']], y_train)
print('-'*40)
print('housePriceUnitArea = w0 + w1*houseAge + w2*distanceToNearestMRTStation')
r2, SST2, SSR2, SSE2 = R2(x_train[['houseAge', 'distanceToNearestMRTStation']], y_train)
print('-'*40)
print('housePriceUnitArea = w0 + w1*houseAge + w2*distanceToNearestMRTStation + w3*numberOfConvenienceStores')
r3, SST3, SSR3, SSE3 = R2(x_train[['houseAge', 'distanceToNearestMRTStation','numberOfConvenienceStores']], y_train)
print('-'*40)
print('housePriceUnitArea = w0 + w1*houseAge + w2*distanceToNearestMRTStation + w3*numberOfConvenienceStores + w4*latitude')
r4, SST4, SSR4, SSE4 = R2(x_train[['houseAge', 'distanceToNearestMRTStation','numberOfConvenienceStores','latitude']], y_train)
print('-'*40)
print('housePriceUnitArea = w0 + w1*houseAge + w2*distanceToNearestMRTStation + w3*numberOfConvenienceStores + w4*latitude + w5*longitude')
r5, SST5, SSR5, SSE5 = R2(x_train, y_train)
print('-'*40)
# Out:
# housePriceUnitArea = w0 + w1*houseAge
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1fb4a221aa67> in <module>
#       1 print('housePriceUnitArea = w0 + w1*houseAge')
# ----> 2 r1, SST1, SSR1, SSE1 = R2(x_train[['houseAge']], y_train)
#       3 print('-'*40)
#       4 print('housePriceUnitArea = w0 + w1*houseAge + w2*distanceToNearestMRTStation')
#       5 r2, SST2, SSR2, SSE2 = R2(x_train[['houseAge', 'distanceToNearestMRTStation']], y_train)
#
# NameError: name 'R2' is not defined

# %%
#Q18 Define a function that calculates R^2_Adjusted

def AdjR2(X_, Y_, r_Sqrd, SST, SSR, SSE):
    
    # Degree of freedomS for SST, SSR, & SSE 
    df_T = # Complete this command
    df_R = # Complete this command
    df_E = # Complete this command

    # Calculate MST
    MST = # Complete this command

    # Calculate MSR
    MSR = # Complete this command

    # Calculate MSE
    MSE = # Complete this command

    Adj_R_sqr = 1 - (MSE/MST)
    
    print('Adjusted R^2 is ', Adj_R_sqr)
    
    return Adj_R_sqr

# %%
print('housePriceUnitArea = w0 + w1*houseAge')
adjR1 = AdjR2(X_train[['houseAge']], y_train,r1,SST1,SSR1,SSE1)
print('-'*40)
print('housePriceUnitArea = w0 + w1*houseAge + w2*distanceToNearestMRTStation')
adjR2 = AdjR2(X_train[['houseAge', 'distanceToNearestMRTStation']], y_train,r2,SST2,SSR2,SSE2)
print('-'*40)
print('housePriceUnitArea = w0 + w1*houseAge + w2*distanceToNearestMRTStation + w3*numberOfConvenienceStores')
adjR3 = AdjR2(X_train[['houseAge', 'distanceToNearestMRTStation','numberOfConvenienceStores']], y_train,r3,SST3,SSR3,SSE3)
print('-'*40)
print('housePriceUnitArea = w0 + w1*houseAge + w2*distanceToNearestMRTStation + w3*numberOfConvenienceStores + w4*latitude')
adjR4 = AdjR2(X_train[['houseAge', 'distanceToNearestMRTStation','numberOfConvenienceStores','latitude']], y_train,r4,SST4,SSR4,SSE4)
print('-'*40)
print('housePriceUnitArea = w0 + w1*houseAge + w2*distanceToNearestMRTStation + w3*numberOfConvenienceStores + w4*latitude + w5*longitude')
adjR5 = AdjR2(X_train, y_train,r5,SST5,SSR5,SSE5)
print('-'*40)

# %%
# This is for SIE433/533 HW 3, Question 2

# we have y_hat as the predicted y
# we have y_train as the true y

# Resetting the index
y_train = y_train.reset_index()
y_train = y_train.drop(['index'], axis = 1)
y_train = y_train.transpose().iloc[0]

summation = 0
# Write a loop to calculate in each iteration: y_hat * ( y - y_hat)
for i in range(len(y_train)):
         summation = # Complete this command

print(summation)
